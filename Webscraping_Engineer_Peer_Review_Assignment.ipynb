# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Webscraping

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# *   Use webscraping to get bank information

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
#!mamba install pandas==1.3.3 -y
#!mamba install requests==2.26.0 -y
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['bs4==4.10.0']
#
# pkgs/main/linux-64       [<=>                 ] (00m:00s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 660 KB / ?? (2.12 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 660 KB / ?? (2.12 MB/s)
# pkgs/r/linux-64          [<=>                 ] (00m:00s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 660 KB / ?? (2.12 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 660 KB / ?? (2.12 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 660 KB / ?? (2.12 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 580 KB / ?? (1.87 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s) Finalizing...
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 580 KB / ?? (1.87 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s) Done
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 580 KB / ?? (1.87 MB/s)
# pkgs/main/noarch         [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 580 KB / ?? (1.87 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Done
# pkgs/r/noarch            [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/main/linux-64       [<=>               ] (00m:00s) 564 KB / ?? (1.82 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.59 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.59 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 596 KB / ?? (1.92 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.59 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) 1 MB / ?? (2.63 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.59 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.59 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Done
# pkgs/r/linux-64          [====================] (00m:00s) Done
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.59 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.59 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.33 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 2 MB / ?? (3.33 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 3 MB / ?? (3.52 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.52 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.71 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 3 MB / ?? (3.71 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 4 MB / ?? (3.86 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:01s) Finalizing...
# pkgs/main/linux-64       [     <=>            ] (00m:01s) Done
# pkgs/main/linux-64       [====================] (00m:01s) Done
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - bs4==4.10.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build           Channel                  Size
# ────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────
#
#   + bs4                  4.10.0  hd3eb1b0_0      pkgs/main/noarch        10 KB
#
#   Change:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - openssl              1.1.1s  h0b41bf4_1      installed
#   + openssl              1.1.1s  h7f8727e_0      pkgs/main/linux-64       4 MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates   2022.9.24  ha878542_0      installed
#   + ca-certificates  2022.10.11  h06a4308_0      pkgs/main/linux-64     124 KB
#   - certifi           2022.9.24  pyhd8ed1ab_0    installed
#   + certifi           2022.12.7  py37h06a4308_0  pkgs/main/linux-64     150 KB
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - beautifulsoup4       4.11.1  pyha770c72_0    installed
#   + beautifulsoup4       4.10.0  pyh06a4308_0    pkgs/main/noarch        85 KB
#
#   Summary:
#
#   Install: 1 packages
#   Change: 1 packages
#   Upgrade: 2 packages
#   Downgrade: 1 packages
#
#   Total download: 4 MB
#
# ────────────────────────────────────────────────────────────────────────────────
#
# Downloading  [>                                        ] (00m:00s)  491.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished beautifulsoup4                       (00m:00s)              85 KB    490 KB/s
# Downloading  [>                                        ] (00m:00s)  491.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  491.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  491.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==>                                      ] (00m:00s)    1.30 MB/s
# Extracting   [>                                                      ] (--:--)
# Finished certifi                              (00m:00s)             150 KB    880 KB/s
# Downloading  [==>                                      ] (00m:00s)    1.30 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==>                                      ] (00m:00s)    1.30 MB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==>                                      ] (00m:00s)    1.30 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [==>                                      ] (00m:00s)    1.30 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [===>                                     ] (00m:00s)    1.90 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Finished ca-certificates                      (00m:00s)             124 KB    701 KB/s
# Downloading  [===>                                     ] (00m:00s)    1.90 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [===>                                     ] (00m:00s)    1.90 MB/s
# Extracting   [========>                                ] (00m:00s)        1 / 5
# Downloading  [===>                                     ] (00m:00s)    1.90 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [===>                                     ] (00m:00s)    1.90 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [===>                                     ] (00m:00s)    1.74 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Finished bs4                                  (00m:00s)              10 KB     50 KB/s
# Downloading  [===>                                     ] (00m:00s)    1.74 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [===>                                     ] (00m:00s)    1.74 MB/s
# Extracting   [================>                        ] (00m:00s)        2 / 5
# Downloading  [===>                                     ] (00m:00s)    1.74 MB/s
# Extracting   [========================>                ] (00m:00s)        3 / 5
# Downloading  [===>                                     ] (00m:00s)    1.74 MB/s
# Extracting   [========================>                ] (00m:00s)        3 / 5
# Downloading  [===>                                     ] (00m:00s)    1.74 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Downloading  [=========================================] (00m:00s)   18.13 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Finished openssl                              (00m:00s)               4 MB     17 MB/s
# Downloading  [=========================================] (00m:00s)   18.13 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Downloading  [=========================================] (00m:00s)   18.13 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Downloading  [=========================================] (00m:00s)   18.13 MB/s
# Extracting   [================================>        ] (00m:00s)        4 / 5
# Downloading  [=========================================] (00m:00s)   18.13 MB/s
# Extracting   [=========================================] (00m:00s)        5 / 5
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['html5lib==1.1']
#
# pkgs/main/linux-64       Using cache
# pkgs/main/noarch         Using cache
# pkgs/r/linux-64          Using cache
# pkgs/r/noarch            Using cache
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - html5lib==1.1
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package         Version  Build         Channel                 Size
# ───────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────
#
#   + html5lib          1.1  pyhd3eb1b0_0  pkgs/main/noarch       91 KB
#   + webencodings    0.5.1  py37_1        pkgs/main/linux-64     19 KB
#
#   Summary:
#
#   Install: 2 packages
#
#   Total download: 110 KB
#
# ───────────────────────────────────────────────────────────────────────
#
# Downloading  [=================================>       ] (00m:00s)  609.54 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished html5lib                             (00m:00s)              91 KB    610 KB/s
# Downloading  [=================================>       ] (00m:00s)  609.54 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  609.54 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  609.54 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  609.54 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Finished webencodings                         (00m:00s)              19 KB     75 KB/s
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [=========================================] (00m:00s)        2 / 2
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
from bs4 import BeautifulSoup
import html5lib
import requests
import pandas as pd

# %% [markdown]
# ## Extract Data Using Web Scraping

# %% [markdown]
# The wikipedia webpage [https://en.wikipedia.org/wiki/List_of_largest_banks](https://en.wikipedia.org/wiki/List_of_largest_banks?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) provides information about largest banks in the world by various parameters. Scrape the data from the table 'By market capitalization' and store it in a JSON file.

# %% [markdown]
# ### Webpage Contents
#
# Gather the contents of the webpage in text format using the `requests` library and assign it to the variable <code>html_data</code>

# %%
#Write your code here
url = 'https://en.wikipedia.org/wiki/List_of_largest_banks'
html_data = requests.get(url).text

html_data
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of largest banks - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"b5ebb534-9fc6-4dac-9d41-7763b833552f","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_largest_banks","wgTitle":"List of largest banks","wgCurRevisionId":1132725388,"wgRevisionId":1132725388,"wgArticleId":38298344,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description is different from Wikidata","Articles containing potentially dated statements from 2022","All articles containing potentially dated statements","Legal entities","Lists of banks","Economy-related lists of superlatives"],\n"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"List_of_largest_banks","wgRelevantArticleId":38298344,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":false,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":10000,"wgNoticeProject":"wikipedia","wgVector2022PreviewPages":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q3679682","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,\n"wgGEStructuredTaskRejectionReasonTextInputEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges":"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips",\n"ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.echo.centralauth","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=s ...

# %% [markdown]
# <b>Question 1</b> Print out the output of the following line, and remember it as it will be a quiz question:

# %%
html_data[101:124]
# Out:
# 'List of largest banks -'

# %% [markdown]
# ### Scraping the Data
#
# <b> Question 2</b> Using the contents and `beautiful soup` load the data from the `By market capitalization` table into a `pandas` dataframe. The dataframe should have the bank `Name` and `Market Cap (US$ Billion)` as column names.  Display the first five rows using head.

# %% [markdown]
# Using BeautifulSoup parse the contents of the webpage.

# %%
#Replace the dots below

soup = BeautifulSoup(html_data, 'html.parser')

tables = soup.find_all('table')
len(tables)
# Out:
# 3

# %% [markdown]
# Load the data from the `By market capitalization` table into a pandas dataframe. The dataframe should have the bank `Name` and `Market Cap (US$ Billion)` as column names. Using the empty dataframe `data` and the given loop extract the necessary data from each row and append it to the empty dataframe.

# %%
data = pd.DataFrame(columns=["Name", "Market Cap (US$ Billion)"])

for row in soup.find_all('tbody')[2].find_all('tr'):
    col = row.find_all('td')
    #Write your code here
    if (col != []):
        name = col[1].text
        market_cap = col[2].text
        data = data.append({"Name": name, "Market Cap (US$ Billion)": market_cap}, ignore_index = True)

data
# Out:
#                                           Name Market Cap (US$ Billion)
# 0                             JPMorgan Chase\n                 368.78\n
# 1    Industrial and Commercial Bank of China\n                 295.65\n
# 2                            Bank of America\n                 279.73\n
# 3                                Wells Fargo\n                 214.34\n
# 4                    China Construction Bank\n                 207.98\n
# 5                 Agricultural Bank of China\n                 181.49\n
# 6                          HSBC Holdings PLC\n                 169.47\n
# 7                             Citigroup Inc.\n                 163.58\n
# 8                              Bank of China\n                 151.15\n
# 9                       China Merchants Bank\n                 133.37\n
# 10                      Royal Bank of Canada\n                 113.80\n
# 11                     Toronto-Dominion Bank\n                 106.61\n
# 12                         Commonwealth Bank\n                  99.77\n
# 13                             Itaú Unibanco\n                  85.68\n
# 14                              U.S. Bancorp\n                  84.40\n
# 15                             Goldman Sachs\n                  78.70\n
# 16                           Banco Santander\n                  75.47\n
# 17                            Morgan Stanley\n                  73.93\n
# 18                                   Westpac\n                  67.84\n
# 19            Mitsubishi UFJ Financial Group\n                  66.20\n
# 20                                Scotiabank\n                  65.48\n
# 21                    PNC Financial Services\n                  63.11\n
# 22                    Bank of Communications\n                  61.85\n
# 23                               BNP Paribas\n                  59.36\n
# 24   Australia and New Zealand Banking Group\n                  54.88\n
# 25                   National Australia Bank\n                  51.68\n
# 26                      Lloyds Banking Group\n                  51.19\n
# 27           Sumitomo Mitsui Financial Group\n                  49.85\n
# 28                          Bank of Montreal\n                  48.12\n
# 29                                       UBS\n                  45.92\n
# 30                                 ING Group\n                  44.97\n
# 31                               Capital One\n                  43.22\n
# 32               The Bank of New York Mellon\n                  42.58\n
# 33                       China Minsheng Bank\n                  39.13\n
# 34                          China CITIC Bank\n                  38.55\n
# 35           Banco Bilbao Vizcaya Argentaria\n                  37.42\n
# 36                    Mizuho Financial Group\n                  36.95\n
# 37                           Intesa Sanpaolo\n                  36.90\n
# 38                           Crédit Agricole\n                  34.89\n
# 39        Canadian Imperial Bank of Commerce\n                  34.87\n
# 40                             NatWest Group\n                  33.95\n
# 41                                  Barclays\n                  33.26\n
# 42                             Credit Suisse\n                  30.75\n
# 43                                    Nordea\n                  29.59\n
# 44                        Standard Chartered\n                  29.37\n
# 45                                  KBC Bank\n                  27.40\n
# 46                                 UniCredit\n                  26.88\n
# 47                          Société Générale\n                  21.27\n
# 48                             Deutsche Bank\n                  15.77\n

# %% [markdown]
# **Question 3** Display the first five rows using the `head` function.

# %%
#Write your code here
data.head()
# Out:
#                                          Name Market Cap (US$ Billion)
# 0                            JPMorgan Chase\n                 368.78\n
# 1   Industrial and Commercial Bank of China\n                 295.65\n
# 2                           Bank of America\n                 279.73\n
# 3                               Wells Fargo\n                 214.34\n
# 4                   China Construction Bank\n                 207.98\n

# %% [markdown]
# ### Loading the Data
#
# Usually you will Load the `pandas` dataframe created above into a JSON named `bank_market_cap.json` using the `to_json()` function, but this time the data will be sent to another team who will split the data file into two files and inspect it. If you save the data it will interfere with the next part of the assignment.

# %%
#Write your code here

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By          | Change Description                 |
# | ----------------- | ------- | ------------------- | ---------------------------------- |
# | 2022-07-12        | 0.2     | Appalabhaktula Hema | Corrected the code and markdown    |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy   | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation.

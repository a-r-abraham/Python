# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # Peer Review Assignment - Data Engineer - Extract API Data

# %% [markdown]
# Estimated time needed: **20** minutes

# %% [markdown]
# ## Objectives
#
# In this part you will:
#
# *   Collect exchange rate data using an API
# *   Store the data as a CSV

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !mamba install pandas==1.3.3 -y
# !mamba install requests==2.26.0 -y

print('fin')
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pandas==1.3.3']
#
# pkgs/main/linux-64       [<=>                 ] (00m:00s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 616 KB / ?? (1.98 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 616 KB / ?? (1.98 MB/s)
# pkgs/r/linux-64          [<=>                 ] (00m:00s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 616 KB / ?? (1.98 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 616 KB / ?? (1.98 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 616 KB / ?? (1.98 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 592 KB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s) Finalizing...
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 592 KB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s) Done
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 592 KB / ?? (1.89 MB/s)
# pkgs/main/noarch         [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 592 KB / ?? (1.89 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Done
# pkgs/r/noarch            [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/main/linux-64       [<=>               ] (00m:00s) 620 KB / ?? (1.99 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.83 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.83 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 332 KB / ?? (1.06 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.83 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 756 KB / ?? (1.52 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.83 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 756 KB / ?? (1.52 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.51 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 756 KB / ?? (1.52 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.51 MB/s)
# pkgs/r/linux-64          [ <=>              ] (00m:00s) 756 KB / ?? (1.52 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.51 MB/s)
# pkgs/r/linux-64          [  <=>               ] (00m:00s) 1 MB / ?? (1.90 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.51 MB/s)
# pkgs/r/linux-64          [  <=>               ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.51 MB/s)
# pkgs/r/linux-64          [  <=>               ] (00m:00s) Done
# pkgs/r/linux-64          [====================] (00m:00s) Done
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.51 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 2 MB / ?? (3.51 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 3 MB / ?? (3.71 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.71 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 4 MB / ?? (3.92 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 4 MB / ?? (3.92 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 4 MB / ?? (4.08 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [     <=>            ] (00m:01s) Done
# pkgs/main/linux-64       [====================] (00m:01s) Done
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - pandas==1.3.3
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build           Channel                  Size
# ────────────────────────────────────────────────────────────────────────────────
#   Change:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - openssl              1.1.1s  h0b41bf4_1      installed
#   + openssl              1.1.1s  h7f8727e_0      pkgs/main/linux-64       4 MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates   2022.9.24  ha878542_0      installed
#   + ca-certificates  2023.01.10  h06a4308_0      pkgs/main/linux-64     120 KB
#   - certifi           2022.9.24  pyhd8ed1ab_0    installed
#   + certifi           2022.12.7  py37h06a4308_0  pkgs/main/linux-64     150 KB
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - pandas                1.3.5  py37h8c16a72_0  installed
#   + pandas                1.3.3  py37h8c16a72_0  pkgs/main/linux-64       9 MB
#
#   Summary:
#
#   Change: 1 packages
#   Upgrade: 2 packages
#   Downgrade: 1 packages
#
#   Total download: 13 MB
#
# ────────────────────────────────────────────────────────────────────────────────
#
# Downloading  [>                                        ] (00m:00s)  445.66 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished ca-certificates                      (00m:00s)             120 KB    445 KB/s
# Downloading  [>                                        ] (00m:00s)  445.66 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  445.66 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  445.66 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  995.22 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished certifi                              (00m:00s)             150 KB    553 KB/s
# Downloading  [>                                        ] (00m:00s)  995.22 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  995.22 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  995.22 KB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [>                                        ] (00m:00s)  995.22 KB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [=====>                                   ] (00m:00s)    6.30 MB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [=====>                                   ] (00m:00s)    6.30 MB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [=========>                               ] (00m:00s)    9.96 MB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [=========>                               ] (00m:00s)    9.96 MB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [=========>                               ] (00m:00s)    9.96 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [===============>                         ] (00m:00s)   14.69 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Finished openssl                              (00m:00s)               4 MB     11 MB/s
# Downloading  [===============>                         ] (00m:00s)   14.69 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [===============>                         ] (00m:00s)   14.69 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [===============>                         ] (00m:00s)   14.69 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=========================================] (00m:00s)   31.37 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Finished pandas                               (00m:00s)               9 MB     22 MB/s
# Downloading  [=========================================] (00m:00s)   31.37 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=========================================] (00m:00s)   31.37 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=========================================] (00m:00s)   31.37 MB/s
# Extracting   [==============================>          ] (00m:00s)        3 / 4
# Downloading  [=========================================] (00m:00s)   31.37 MB/s
# Extracting   [==============================>          ] (00m:00s)        3 / 4
# Downloading  [=========================================] (00m:01s)   31.37 MB/s
# Extracting   [=========================================] (00m:01s)        4 / 4
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['requests==2.26.0']
#
# pkgs/main/linux-64       Using cache
# pkgs/main/noarch         Using cache
# pkgs/r/linux-64          Using cache
# pkgs/r/noarch            Using cache
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - requests==2.26.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build         Channel               Size
# ───────────────────────────────────────────────────────────────────────────
#   Downgrade:
# ───────────────────────────────────────────────────────────────────────────
#
#   - charset-normalizer    2.1.1  pyhd8ed1ab_0  installed
#   + charset-normalizer    2.0.4  pyhd3eb1b0_0  pkgs/main/noarch     35 KB
#   - requests             2.28.1  pyhd8ed1ab_1  installed
#   + requests             2.26.0  pyhd3eb1b0_0  pkgs/main/noarch     59 KB
#
#   Summary:
#
#   Downgrade: 2 packages
#
#   Total download: 94 KB
#
# ───────────────────────────────────────────────────────────────────────────
#
# Downloading  [==============>                          ] (00m:00s)  231.83 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished charset-normalizer                   (00m:00s)              35 KB    231 KB/s
# Downloading  [==============>                          ] (00m:00s)  231.83 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==============>                          ] (00m:00s)  231.83 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==============>                          ] (00m:00s)  231.83 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==============>                          ] (00m:00s)  231.83 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [===============>                         ] (00m:00s)  209.94 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [===============>                         ] (00m:00s)  209.94 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  555.04 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Finished requests                             (00m:00s)              59 KB    352 KB/s
# Downloading  [=========================================] (00m:00s)  555.04 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  555.04 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  555.04 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  555.04 KB/s
# Extracting   [=========================================] (00m:00s)        2 / 2
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import requests
import pandas as pd
import json
print('fin')
# Out:
# fin

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# Using ExchangeRate-API we will extract currency exchange rate data. Use the below steps to get the access key and to get the data.
#
# 1.  Open the url : [https://exchangeratesapi.io/](https://exchangeratesapi.io/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) and click on **Get Free API Key**.
# 2.  Subscribe for Free plan and Sign-in with the Google Account.
# 3.  Once the account is created you will be redirected to [https://apilayer.com](https://apilayer.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) website.
# 4.  Now, click on the **user icon** and click **Account** as shown below:
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/Images/account.png"/>
#
# 3.  Scroll down and you will get the API Key section. Copy the API key and use in the url in Question 1.

# %% [markdown]
# ### Call the API
#
# <b> Question 1</b> Using the `requests` library call the endpoint given above and save the text, remember the first few characters of the output:

# %%
# Write your code here
url = "https://api.apilayer.com/exchangerates_data/latest?base=EUR&apikey=ZH2FFVgsFpqpxukN11892huMBM0rETmm" #Make sure to change ******* to your API key.

data = requests.get("https://api.apilayer.com/exchangerates_data/latest?base=EUR&apikey=ZH2FFVgsFpqpxukN11892huMBM0rETmm")
results = json.loads(data.text)
results
# Out:
# {'success': True,
#  'timestamp': 1674748864,
#  'base': 'EUR',
#  'date': '2023-01-26',
#  'rates': {'AED': 3.986601,
#   'AFN': 96.050357,
#   'ALL': 115.990501,
#   'AMD': 429.419143,
#   'ANG': 1.958255,
#   'AOA': 547.613264,
#   'ARS': 201.154878,
#   'AUD': 1.531782,
#   'AWG': 1.953633,
#   'AZN': 1.8411,
#   'BAM': 1.949117,
#   'BBD': 2.19332,
#   'BDT': 115.148118,
#   'BGN': 1.948815,
#   'BHD': 0.40924,
#   'BIF': 2238.538061,
#   'BMD': 1.085352,
#   'BND': 1.424951,
#   'BOB': 7.506348,
#   'BRL': 5.517716,
#   'BSD': 1.086298,
#   'BTC': 4.7197081e-05,
#   'BTN': 88.545018,
#   'BWP': 13.823987,
#   'BYN': 2.742554,
#   'BYR': 21272.895027,
#   'BZD': 2.189634,
#   'CAD': 1.450817,
#   'CDF': 2218.459581,
#   'CHF': 1.000629,
#   'CLF': 0.031642,
#   'CLP': 873.979281,
#   'CNY': 7.362488,
#   'COP': 4920.691958,
#   'CRC': 611.098837,
#   'CUC': 1.085352,
#   'CUP': 28.761822,
#   'CVE': 110.298865,
#   'CZK': 23.814794,
#   'DJF': 193.433768,
#   'DKK': 7.437449,
#   'DOP': 61.607808,
#   'DZD': 147.574199,
#   'EGP': 32.443441,
#   'ERN': 16.280277,
#   'ETB': 58.279909,
#   'EUR': 1,
#   'FJD': 2.340724,
#   'FKP': 0.877281,
#   'GBP': 0.878506,
#   'GEL': 2.870735,
#   'GGP': 0.877281,
#   'GHS': 13.473394,
#   'GIP': 0.877281,
#   'GMD': 67.076005,
#   'GNF': 9357.470618,
#   'GTQ': 8.524041,
#   'GYD': 229.205653,
#   'HKD': 8.495309,
#   'HNL': 26.797702,
#   'HRK': 7.643262,
#   'HTG': 161.715015,
#   'HUF': 387.535941,
#   'IDR': 16246.793704,
#   'ILS': 3.70854,
#   'IMP': 0.877281,
#   'INR': 88.460892,
#   'IQD': 1585.823431,
#   'IRR': 45801.845635,
#   'ISK': 156.095665,
#   'JEP': 0.877281,
#   'JMD': 167.097476,
#   'JOD': 0.769842,
#   'JPY': 141.555898,
#   'KES': 134.963666,
#   'KGS': 93.473206,
#   'KHR': 4464.752768,
#   'KMF': 489.737872,
#   'KPW': 976.776747,
#   'KRW': 1340.376652,
#   'KWD': 0.331488,
#   'KYD': 0.905481,
#   'KZT': 500.755278,
#   'LAK': 18296.414168,
#   'LBP': 1642.748452,
#   'LKR': 395.508872,
#   'LRD': 169.858876,
#   'LSL': 18.68959,
#   'LTL': 3.204762,
#   'LVL': 0.656518,
#   'LYD': 5.169794,
#   'MAD': 11.00091,
#   'MDL': 20.421962,
#   'MGA': 4624.843029,
#   'MKD': 61.422687,
#   'MMK': 2281.237091,
#   'MNT': 3771.710233,
#   'MOP': 8.762838,
#   'MRO': 387.470401,
#   'MUR': 48.135072,
#   'MVR': 16.681569,
#   'MWK': 1115.286684,
#   'MXN': 20.449917,
#   'MYR': 4.607865,
#   'MZN': 69.277703,
#   'NAD': 18.690094,
#   'NGN': 499.566069,
#   'NIO': 39.703252,
#   'NOK': 10.75836,
#   'NPR': 141.705931,
#   'NZD': 1.678898,
#   'OMR': 0.417802,
#   'PAB': 1.086298,
#   'PEN': 4.2348,
#   'PGK': 3.828578,
#   'PHP': 59.12128,
#   'PKR': 263.219808,
#   'PLN': 4.711968,
#   'PYG': 8024.063194,
#   'QAR': 3.951798,
#   'RON': 4.874424,
#   'RSD': 117.348165,
#   'RUB': 75.24205,
#   'RWF': 1173.109528,
#   'SAR': 4.073842,
#   'SBD': 8.951697,
#   'SCR': 15.351379,
#   'SDG': 625.705734,
#   'SEK': 11.20147,
#   'SGD': 1.425604,
#   'SHP': 1.494968,
#   'SLE': 21.001869,
#   'SLL': 20909.302171,
#   'SOS': 618.109128,
#   'SRD': 34.731071,
#   'STD': 22464.590676,
#   'SVC': 9.507255,
#   'SYP': 2726.863397,
#   'SZL': 18.562666,
#   'THB': 35.62234,
#   'TJS': 11.153584,
#   'TMT': 3.809585,
#   'TND': 3.353532,
#   'TOP': 2.508736,
#   'TRY': 20.415572,
#   'TTD': 7.373438,
#   'TWD': 32.849801,
#   'TZS': 2536.796016,
#   'UAH': 39.932762,
#   'UGX': 3997.57376,
#   'USD': 1.085352,
#   'UYU': 42.544076,
#   'UZS': 12299.916127,
#   'VEF': 2294854.708156,
#   'VES': 22.952946,
#   'VND': 25451.499407,
#   'VUV': 125.410317,
#   'WST': 2.885742,
#   'XAF': 653.699479,
#   'XAG': 0.045636,
#   'XAU': 0.000564,
#   'XCD': 2.933217,
#   'XDR': 0.80502,
#   'XOF': 653.705481,
#   'XPF': 121.656729,
#   'YER': 271.744946,
#   'ZAR': 18.697377,
#   'ZMK': 9769.462081,
#   'ZMW': 20.509447,
#   'ZWL': 349.482833}}

# %% [markdown]
# ### Save as DataFrame
#
# <b> Question 2</b>  Using the data gathered turn it into a `pandas` dataframe. The dataframe should have the Currency as the index and `Rate` as their columns. Make sure to drop unnecessary columns.

# %%
# Turn the data into a dataframe
df = pd.DataFrame(results)
df
# Out:
#      success   timestamp base        date        rates
# AED     True  1674748864  EUR  2023-01-26     3.986601
# AFN     True  1674748864  EUR  2023-01-26    96.050357
# ALL     True  1674748864  EUR  2023-01-26   115.990501
# AMD     True  1674748864  EUR  2023-01-26   429.419143
# ANG     True  1674748864  EUR  2023-01-26     1.958255
# ..       ...         ...  ...         ...          ...
# YER     True  1674748864  EUR  2023-01-26   271.744946
# ZAR     True  1674748864  EUR  2023-01-26    18.697377
# ZMK     True  1674748864  EUR  2023-01-26  9769.462081
# ZMW     True  1674748864  EUR  2023-01-26    20.509447
# ZWL     True  1674748864  EUR  2023-01-26   349.482833
#
# [170 rows x 5 columns]

# %%
# Drop unnescessary columns
del df['success']
del df['timestamp']
del df['base']
del df['date']

df
# Out:
#            rates
# AED     3.986601
# AFN    96.050357
# ALL   115.990501
# AMD   429.419143
# ANG     1.958255
# ..           ...
# YER   271.744946
# ZAR    18.697377
# ZMK  9769.462081
# ZMW    20.509447
# ZWL   349.482833
#
# [170 rows x 1 columns]

# %% [markdown]
# ### Load the Data
#
# Using the dataframe save it as a CSV names `exchange_rates_1.csv`.

# %%
# Save the Dataframe
df.to_csv('exchange_rates_1.csv')

# %% [markdown]
# Your CSV should be in this format with more currencies
#
# |     | Rates      |
# | --- | ---------- |
# | AED | 4.398618   |
# | AFN | 92.917693  |
# | ALL | 123.099093 |
# | AMD | 621.935674 |
# | ANG | 2.149648   |

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy, Joseph Santarcangelo and Azim Hirjani

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                              |
# | ----------------- | ------- | ----------------- | ----------------------------------------------- |
# | 2022-05-06        | 0.3     | Malika            | Updated instructions to get the API and the url |
# | 2021-04-15        | 0.2     | Malika            | Updated the lab from USD to EUR                 |
# | 2020-11-25        | 0.1     | Ramesh Sannareddy | Created initial version of the lab              |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
